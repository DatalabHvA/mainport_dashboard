# %%
import pandas as pd

# %% [markdown]
# bron: https://www.cbs.nl/nl-nl/maatwerk/2025/40/bedrijfseconomische-schets-schiphol-cluster-2010-2025

# %% [markdown]
# ## toegevoegde waarde per passagier/ton cargo schiphol cluster

# %%
#tabel 3 - passagiersvervoer
(4233 + 726 + (768*(2/3)))/71 #71 miljoen passagiers vervoerd in 2023 https://www.schiphol.nl/nl/download/b2b/1708066095/6FIsfJ3Ab26LkQNXZrsMsC.pdf
# Out:
# 77.05633802816901

# %%
# tabel 3 - vrachtvervoer + 1/3 van vliegtuig en luchthaventechniek 
(2100 + (768*(1/3)))/1.38 # 1.38 miljoen ton vracht https://www.schiphol.nl/nl/download/b2b/1708066095/6FIsfJ3Ab26LkQNXZrsMsC.pdf
# Out:
# 1707.2463768115942

# %% [markdown]
# ## werkgelegenheid waarde per passagier/ton cargo schiphol cluster

# %%
#tabel 4 - passagiersvervoer
(36044 + 14042+(7626*(2/3)))/71000000 #61 miljoen passagiers vervoerd in 2023
# Out:
# 0.0007770422535211268

# %%
#tabel 4 - passagiersvervoer
(22666 + (7626*(1/3)))/1380000 #61 miljoen passagiers vervoerd in 2023
# Out:
# 0.018266666666666667
